# %% [markdown]
# # Matplotlib
#
# Lib de python para realizar graficos (2D) sirve de backend ploty + seaborn
#
# - Dispersión (scatter plots)
# - Linea
# - Barras
# - Histogramas
# - Boxplot (caja y bigote) (el que le gusta a franco :P )
# - Violin
# - Mapas de calor
# - Torta (Pastel)

# %%
pip install matplotlib
# Out:
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 23.2.1
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Numpy
#
# Vectores, matrices, tensores (C,C++) int vector[10]

# %%
x = np.array([1,2,6,8])
y = np.array([3,7,2,8])
# P0 = (1,3)
# P1 = (2,7)
# ...
# Pn = (8,8)

plt.plot(x,y, linestyle='dotted',ms=20, marker='*',color='g') # figure #c
plt.show()

# %%
plt.plot(x,y, linewidth=10.5, c='purple')

# %%
y1 = np.array([-3,-8,1,100])
y2 = np.array([6,2,7,20])

plt.plot(y1,c='r')
plt.plot(y2,c='blue', linestyle='dotted')
plt.show()

# %% [markdown]
# ### Pulsaciones  vs  Cansancio (0-100)

# %%
x = np.array([50,61,63,78,80,100,110,120,170])
y = np.array([20,40,42,55,65,72,80,84,99])

plt.plot(x,y, c='green', label='Cansancio promedio')
plt.xlabel("Pulsaciones")
plt.ylabel("Cansancio")
plt.grid() # grilla en mi figura
plt.title("Pulsaciones vs Cansancio", loc='center') # 'best'
plt.legend(loc='best') # fran no se lo acordaba :P 
plt.show()

# %% [markdown]
# ## Subplots
#
# Con subplot() podemos dibujar múltiples gráficos en una sola figura
# La función subplot toma 3 argumentos (posicionales) que describen un layout está organizando en filas y columnas
#
# plt.subplot(1,2,1)

# %%
x1 = np.array([0,1,2,3])
y1 = np.array([1,2,4,5])
x2 = np.array([0,1,2])
y2 = np.array([2,4,6])

plt.subplot(1,2,1)
# color | c enum
plt.plot(x1,y1,'#ffefd5',label='grafico papayawip') #primer columna de mi layout
plt.grid()
plt.title("Primer gráfico")
plt.legend(loc='best') # fran no se lo acordaba :P 
plt.subplot(1,2,2)

plt.plot(x2,y2,c='r', label='otro gráfico')
plt.legend(loc='best') # fran no se lo acordaba :P 
plt.grid()
plt.suptitle("El titulo del proyecto / todos los graficos")
plt.show()

# %% [markdown]
# # Tipos de gráficos
#
# - Scatter (dispersión)
# - Bars
# - Histogramas
# - Caja

# %%
x = np.array([1,2,5,7,10,12,20])
y = np.array([100,200,480,570,600,1000,2000])

len(x), len(y)
# Out:
# (7, 7)

# %%
try:
    
    plt.scatter(x,y,c='r', marker="*")
    plt.title("Ingreso promedio vs años trabajados", loc='left')
    plt.xlabel("Años trabajados")
    plt.ylabel("Salario promedio en USD")
    plt.grid()
    plt.show()
except:
    print("La variabel x e y tiene que tener la misma dimensión")

# %%
import pandas as pd

# %%
data = pd.read_csv("https://interactivechaos.com/sites/default/files/data/iris_data_set.csv")

# %%
data.shape
# Out:
# (150, 5)

# %%
data.sample(3)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 93            5.0          2.3           3.3          1.0  versicolor
# 107           7.3          2.9           6.3          1.8   virginica
# 144           6.7          3.3           5.7          2.5   virginica

# %%
data.species
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %% [markdown]
# Vamos a cruzar sepal_length vs sepal_width (x,y) vamos a empezar a mezclar este gráfico con el color

# %%
set(data.species) # es un tipo de datos que no admite duplicados
# Out:
# {'setosa', 'versicolor', 'virginica'}

# %%
plt.scatter(data['sepal_length'],data['sepal_width'],c='r')

# %%
colors = {
    'setosa':'red',
    'versicolor':'blue',
    'virginica':'pink'
}

# %%
for specie in data.species:
    if specie === 'setosa':
        return 'red'
    elif specie=='versicolor':
        return 'blue'
    else:
        return 'pink'

# %%
species_color = pd.Series(data.species.map(colors))
species_color
# Out:
# 0       red
# 1       red
# 2       red
# 3       red
# 4       red
#        ...
# 145    pink
# 146    pink
# 147    pink
# 148    pink
# 149    pink
# Name: species, Length: 150, dtype: object

# %%
data['species_color'] = species_color

# %%
data.sample(2)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species species_color
# 39           5.1          3.4           1.5          0.2  setosa           red
# 38           4.4          3.0           1.3          0.2  setosa           red

# %%
plt.scatter(data.sepal_length,data.sepal_width,c=data.species_color)
plt.show()

# %%
# Nef nos debe el ejemplo!

# %% [markdown]
# # Gráfico de barras
#
# Discretas (diagrama de frecuencias)
# Frecuencia: relación que cuenta las apariciones de un elemento dentro de un conjunto

# %%
gender = ['Hombre','Mujer','Otro']
quantity = [20,30,10]

plt.bar(gender,quantity,color=['red','green','blue'])
plt.xlabel("Genero")
plt.ylabel("Frecuencia")
plt.grid()
plt.show()

# %% [markdown]
# ## Histogramas
#
# Simboliza la distribución de un conjunto de datos (continuo). Sirve para obtener una primera vista de una distribución de la población (cuantitativa continua)
#
# ### p-valores y intervalos de confianza
#
# Puedo asegurar con un 80% de confianza que la media de mi poblacion es de 1.74

# %%
import seaborn as sns

# %%
from sklearn.datasets import fetch_openml

# %%
titanic = fetch_openml('titanic', version=1)
titanic
# Out:
# {'data':       pclass                                             name     sex  \
#  0        1.0                    Allen, Miss. Elisabeth Walton  female
#  1        1.0                   Allison, Master. Hudson Trevor    male
#  2        1.0                     Allison, Miss. Helen Loraine  female
#  3        1.0             Allison, Mr. Hudson Joshua Creighton    male
#  4        1.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#  ...      ...                                              ...     ...
#  1304     3.0                             Zabour, Miss. Hileni  female
#  1305     3.0                            Zabour, Miss. Thamine  female
#  1306     3.0                        Zakarian, Mr. Mapriededer    male
#  1307     3.0                              Zakarian, Mr. Ortin    male
#  1308     3.0                               Zimmerman, Mr. Leo    male
#
#            age  sibsp  parch  ticket      fare    cabin embarked  boat   body  \
# ...

# %%
titanic_df = pd.DataFrame(data=titanic['data'])
titanic_df.sample(3)
# Out:
#       pclass                                            name     sex   age  \
# 425      2.0                           Greenberg, Mr. Samuel    male  52.0
# 610      3.0  Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0
# 1019     3.0                                Mineff, Mr. Ivan    male  24.0
#
#       sibsp  parch  ticket     fare cabin embarked  boat  body  \
# 425     0.0    0.0  250647  13.0000  None        S  None  19.0
# 610     1.0    0.0    7546   9.4750  None        S  None   NaN
# 1019    0.0    0.0  349233   7.8958  None        S  None   NaN
#
#               home.dest
# 425           Bronx, NY
# 610   Sweden Akeley, MN
# 1019               None

# %%
titanic_df.shape
# Out:
# (1309, 13)

# %%
sns.histplot(x=titanic_df['age'], kde=True)
# Out:
# <AxesSubplot: xlabel='age', ylabel='Count'>

# %%
sns.boxenplot(data=titanic_df['age'])
# Out:
# <AxesSubplot: >

# %%
# bins = [[0,5),[5,10),[10,15)]]]
